# %%
import pandas as pd
import numpy as np

# %%
A = pd.read_excel("DrugInformation_ImmuneModPaper.xlsx")

# %%
B = pd.read_csv("structure links_1.csv")

# %%
D['CHEMBL_ID']
# Out:
# 0        CHEMBL222280
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 1397    CHEMBL1537401
# 1398       CHEMBL1175
# 1399        CHEMBL163
# 1400    CHEMBL1472975
# 1401        CHEMBL499
# Name: CHEMBL_ID, Length: 1402, dtype: object

# %%
D = pd.DataFrame(A)

# %%
D.head()
# Out:
#                                             SMILES  CHEMSPIDER_ID  \
# 0  BrC1=CN([C@@H]2O[C@H](CO)[C@@H](O)C2)C(=O)NC1=O         5813.0
# 1                  BrC1=Cn2c3c(nccc3c3c2cccc3)C1=O            NaN
# 2                   BrCC(=O)c1nccc2c1n(c1c2cccc1)C            NaN
# 3                       Brc1c2[nH]c3c(c2ccc1)cccc3      9405383.0
# 4                    Brc1c2[nH]c3c(c2ccc1OC)ccnc3C      9132463.0
#
#       CHEMBL_ID CHEMBL_KNOWN_DRUG  CHEMBL_NAME  \
# 0  CHEMBL222280                No  BROXURIDINE
# 1           NaN               NaN          NaN
# 2           NaN               NaN          NaN
# 3           NaN               NaN          NaN
# 4           NaN               NaN          NaN
#
#                                CHEMBL_ALTERNATE_NAME  CLINICALTRIALS_DB  \
# 0  SID50105447|SID17389223|SID90341500|SID5646351...                  1
# 1                                                NaN                  0
# 2                                                NaN                  0
# 3                                                NaN                  0
# 4                                                NaN                  0
#
#   CONCENTRATION_uM
# 0               10
# 1               20
# 2               20
# 3               20
# 4               20

# %%
E = pd.DataFrame(B)

# %%
D.columns,E.columns
# Out:
# (Index(['SMILES', 'CHEMSPIDER_ID', 'CHEMBL_ID', 'CHEMBL_KNOWN_DRUG',
#         'CHEMBL_NAME', 'CHEMBL_ALTERNATE_NAME', 'CLINICALTRIALS_DB',
#         'CONCENTRATION_uM'],
#        dtype='object'),
#  Index(['DrugBank ID', 'Name', 'CAS Number', 'Drug Groups', 'InChIKey', 'InChI',
#         'SMILES', 'Formula', 'KEGG Compound ID', 'KEGG Drug ID',
#         'PubChem Compound ID', 'PubChem Substance ID', 'ChEBI ID', 'CHEMBL_ID',
#         'HET ID', 'ChemSpider ID', 'BindingDB ID'],
#        dtype='object'))

# %%
S = np.array(D)

# %%
S[0][0]
# Out:
# 'BrC1=CN([C@@H]2O[C@H](CO)[C@@H](O)C2)C(=O)NC1=O'

# %%
type(D['CHEMBL_ID'])
# Out:
# pandas.core.series.Series

# %%
type(E['CHEMBL_ID'])
# Out:
# pandas.core.series.Series

# %%
F = np.array(A)

# %%
G = np.array(B)

# %%
G[0][13]
# Out:
# 'CHEMBL2103749'

# %%
T = []
for i in range(0, len(F)):
    CHEM = F[i][2]
    for j in range(0, len(G)):
        CHEM2 = G[j][13]
        if CHEM == CHEM2:
            T.append([F[i][2],G[j][:10]])

# %%
len(T)
# Out:
# 766

# %%
Z = pd.DataFrame.from_items(T)
# Out:
# /Users/eric/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   """Entry point for launching an IPython kernel.

# %%
len(Z)
# Out:
# 10

# %%
Y = pd.DataFrame.transpose(Z)

# %%
len(Y)
# Out:
# 766

# %%
Y.head()
# Out:
#                      0                   1           2  \
# CHEMBL222280   DB12028         Broxuridine     59-14-3
# CHEMBL844      DB00484         Brimonidine  59803-98-4
# CHEMBL388590   DB12319       Benzbromarone   3562-84-3
# CHEMBL1201287  DB00405  Dexbrompheniramine    132-21-8
# CHEMBL1199080  DB01158           Bretylium     59-41-6
#
#                                         3                            4  \
# CHEMBL222280              investigational  WOVKYSAHUYNSMH-RRKCRQDMSA-N
# CHEMBL844                        approved  XYLJNLCSTIOKRM-UHFFFAOYSA-N
# CHEMBL388590   investigational; withdrawn  WHQCHUCQKNIQEC-UHFFFAOYSA-N
# CHEMBL1201287                    approved  ZDIGNSYAACHWNL-HNNXBMFYSA-N
# CHEMBL1199080                    approved  AAQOQKQBGPPFNS-UHFFFAOYSA-N
#
#                                                                5  \
# CHEMBL222280   InChI=1S/C9H11BrN2O5/c10-4-2-12(9(16)11-8(4)15...
# CHEMBL844      InChI=1S/C11H10BrN5/c12-9-7(17-11-15-5-6-16-11...
# CHEMBL388590   InChI=1S/C17H12Br2O3/c1-2-13-15(10-5-3-4-6-14(...
# CHEMBL1201287  InChI=1S/C16H19BrN2/c1-19(2)12-10-15(16-5-3-4-...
# CHEMBL1199080  InChI=1S/C11H17BrN/c1-4-13(2,3)9-10-7-5-6-8-11...
#
#                                                                6            7  \
# CHEMBL222280   [H][C@]1(O)C[C@@]([H])(O[C@]1([H])CO)N1C=C(Br)...  C9H11BrN2O5
# CHEMBL844                       BrC1=C(NC2=NCCN2)C=CC2=NC=CN=C12   C11H10BrN5
# CHEMBL388590    CCC1=C(C(=O)C2=CC(Br)=C(O)C(Br)=C2)C2=CC=CC=C2O1  C17H12Br2O3
# CHEMBL1201287          CN(C)CC[C@@H](C1=CC=C(Br)C=C1)C1=CC=CC=N1   C16H19BrN2
# CHEMBL1199080                         CC[N+](C)(C)CC1=CC=CC=C1Br    C11H17BrN
#
#                     8       9
# CHEMBL222280      NaN     NaN
# CHEMBL844      C07886  D07540
# CHEMBL388590      NaN  D01056
# CHEMBL1201287     NaN     NaN
# CHEMBL1199080  C06855  D00645

# %%
set(D.columns).intersection(set(E.columns))
# Out:
# {'CHEMBL_ID', 'SMILES'}

# %%
D['CHEMBL_ID'].isin(E['CHEMBL_ID']).value_counts()
# Out:
# True     1043
# False     359
# Name: CHEMBL_ID, dtype: int64

# %%
cnt = 0
for i in D['CHEMBL_ID']:
    if type(i)==float:
        cnt += 1
print(cnt)
print(1043-277)
# Out:
# 277
# 766

# %%
from rdkit import Chem
from mordred import Calculator, descriptors
calc = Calculator(descriptors, ignore_3D = True)
Y[6][0]
# Out:
# '[H][C@]1(O)C[C@@]([H])(O[C@]1([H])CO)N1C=C(Br)C(O)=NC1=O'

# %%
smiles = []
for i in Y[6]:
    smiles.append(i)

# %%
len(smiles)
# Out:
# 766

# %%
## trying pandas merge/inner join

attempt = pd.merge(D,E, on = 'CHEMBL_ID', how = 'inner')

# %%
len(attempt)
# Out:
# 1015971

# %%
attempt
# Out:
#                                                   SMILES_x  CHEMSPIDER_ID  \
# 0          BrC1=CN([C@@H]2O[C@H](CO)[C@@H](O)C2)C(=O)NC1=O         5813.0
# 1                          BrC1=Cn2c3c(nccc3c3c2cccc3)C1=O            NaN
# 2                          BrC1=Cn2c3c(nccc3c3c2cccc3)C1=O            NaN
# 3                          BrC1=Cn2c3c(nccc3c3c2cccc3)C1=O            NaN
# 4                          BrC1=Cn2c3c(nccc3c3c2cccc3)C1=O            NaN
# ...                                                    ...            ...
# 1015966  s1cccc1CC(=O)N[C@@]1(OC)[C@H]2SCC(COC(=O)N)=C(...       389981.0
# 1015967               s1cccc1[C@@H](Oc1c2c(ccc1)cccc2)CCNC        54822.0
# 1015968  s1cncc1COC(=O)N[C@H]([C@@H](O)C[C@@H](NC(=O)[C...       347980.0
# 1015969  s1nc(N2CCN(CC2)CCCCN2C(=O)[C@H]3[C@H](CCCC3)C2...       103202.0
# 1015970           s1nc(N2CCOCC2)c(OC[C@@H](O)CNC(C)(C)C)n1        31013.0
#
#              CHEMBL_ID CHEMBL_KNOWN_DRUG  CHEMBL_NAME  \
# 0         CHEMBL222280                No  BROXURIDINE
# 1                  NaN               NaN          NaN
# 2                  NaN               NaN          NaN
# 3                  NaN               NaN          NaN
# 4                  NaN               NaN          NaN
# ...                ...               ...          ...
# 1015966      CHEMBL996               Yes    CEFOXITIN
# 1015967     CHEMBL1175               Yes   DULOXETINE
# 1015968      CHEMBL163               Yes    RITONAVIR
# 1015969  CHEMBL1472975                No  PEROSPIRONE
# 1015970      CHEMBL499               Yes      TIMOLOL
#
#                                      CHEMBL_ALTERNATE_NAME  CLINICALTRIALS_DB  \
# 0        SID50105447|SID17389223|SID90341500|SID5646351...                  1
# 1                                                      NaN                  0
# 2                                                      NaN                  0
# 3                                                      NaN                  0
# 4                                                      NaN                  0
# ...                                                    ...                ...
# 1015966  Cenomycin|Mefoxin|Cefoxitin|SID144206560|Mefox...                 18
# 1015967  SID26757978|Duloxetine|SID26719725|Cymbalta|SI...                600
# 1015968  A-84538|ABBOTT-84538|SID26719904|SID144206981|...               1605
# 1015969                           Perospirone|SID26757988|                  0
# 1015970  SID11111904|SID144204165|Betimol|Timolol|Istal...                553
#
#         CONCENTRATION_uM DrugBank ID                 Name  ...  \
# 0                     10     DB12028          Broxuridine  ...
# 1                     20     DB00144  Phosphatidyl serine  ...
# 2                     20     DB00157                 NADH  ...
# 3                     20     DB00185           Cevimeline  ...
# 4                     20     DB00225          Gadodiamide  ...
# ...                  ...         ...                  ...  ...
# 1015966               10     DB01331            Cefoxitin  ...
# 1015967               10     DB00476           Duloxetine  ...
# 1015968               10     DB00503            Ritonavir  ...
# 1015969               10     DB08922          Perospirone  ...
# 1015970               10     DB00373              Timolol  ...
#
#                                                   SMILES_y        Formula  \
# 0        [H][C@]1(O)C[C@@]([H])(O[C@]1([H])CO)N1C=C(Br)...    C9H11BrN2O5
# 1        CCCC(=O)O[C@H](COC(=O)CC)COP(O)(=O)OC[C@H](N)C...    C13H24NO10P
# 2        NC(=O)C1=CN(C=CC1)[C@@H]1O[C@H](CO[P@](O)(=O)O...  C21H29N7O14P2
# 3                                CC1O[C@@]2(CS1)CN1CCC2CC1      C10H17NOS
# 4        O=C1[O-][Gd+3]234567[O]=C(C[N]2(CC[N]3(CC([O-]...   C16H26GdN5O8
# ...                                                    ...            ...
# 1015966  [H][C@]12SCC(COC(N)=O)=C(N1C(=O)[C@]2(NC(=O)CC...   C16H17N3O7S2
# 1015967           CNCC[C@H](OC1=CC=CC2=CC=CC=C12)C1=CC=CS1      C18H19NOS
# 1015968  CC(C)[C@H](NC(=O)N(C)CC1=CSC(=N1)C(C)C)C(=O)N[...   C37H48N6O5S2
# 1015969  [H][C@@]12CCCC[C@]1([H])C(=O)N(CCCCN1CCN(CC1)C...    C23H30N4O2S
# 1015970          [H][C@](O)(CNC(C)(C)C)COC1=NSN=C1N1CCOCC1    C13H24N4O3S
#
#         KEGG Compound ID KEGG Drug ID PubChem Compound ID  \
# 0                    NaN          NaN              6035.0
# 1                    NaN          NaN           6323481.0
# 2                 C00004          NaN            439153.0
# 3                    NaN       D00661          25137844.0
# 4                    NaN          NaN          24847884.0
# ...                  ...          ...                 ...
# 1015966           C06887       D02345            441199.0
# 1015967              NaN       D01179             60835.0
# 1015968           C07240       D00427            392622.0
# 1015969              NaN          NaN            115368.0
# 1015970           C07141          NaN             33624.0
#
#         PubChem Substance ID  ChEBI ID HET ID  ChemSpider ID  BindingDB ID
# 0                347828343.0  472552.0    U33         5813.0    50207303.0
# 1                 46505650.0   18303.0    PSF     13628254.0           NaN
# 2                 46504879.0   16908.0    NAI       388299.0           NaN
# 3                 46507202.0    3568.0    NaN     21864737.0           NaN
# 4                 46504789.0   37333.0    NaN       135661.0           NaN
# ...                      ...       ...    ...            ...           ...
# 1015966           46505845.0  209807.0    CFX       389981.0    50335563.0
# 1015967           46507937.0   36795.0    29E        54822.0       84745.0
# 1015968           46505050.0   45409.0    RIT       347980.0         520.0
# 1015969          310264903.0   94777.0    NaN       103202.0           NaN
# 1015970           46507733.0    9599.0    TIM        31013.0    50292219.0
#
# [1015971 rows x 24 columns]
