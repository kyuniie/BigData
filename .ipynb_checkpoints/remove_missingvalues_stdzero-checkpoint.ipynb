# %%
import pandas as pd
import numpy as np
trainingSetDF = pd.read_excel("DrugInformation_ImmuneModPaper.xlsx")
###Drop duplicates (certain drugs listed multiple times with slightly different smiles)
trainingSetDF = trainingSetDF.drop_duplicates(subset = "CHEMBL_ID")
##Remove compounds without ChEMBL IDs
trainingSetDF = trainingSetDF[~pd.isna(trainingSetDF.CHEMBL_ID)]
drugBankDF = pd.read_csv("structure links_1.csv")
##Remove compounds without ChEMBL IDs
drugBankDF = drugBankDF[~pd.isna(drugBankDF.CHEMBL_ID)]
##How many drugs overlap between the training set and drugbank?
overlap = len(set(trainingSetDF.CHEMBL_ID.unique()).intersection(set(drugBankDF.CHEMBL_ID.unique())))
print(overlap)
##Merge
combinedDF = pd.merge(trainingSetDF, drugBankDF, on= "CHEMBL_ID", how = "inner")
assert combinedDF.shape[0] == overlap
# Out:
# 747

# %%
combinedDF.columns
# Out:
# Index(['SMILES_x', 'CHEMSPIDER_ID', 'CHEMBL_ID', 'CHEMBL_KNOWN_DRUG',
#        'CHEMBL_NAME', 'CHEMBL_ALTERNATE_NAME', 'CLINICALTRIALS_DB',
#        'CONCENTRATION_uM', 'DrugBank ID', 'Name', 'CAS Number', 'Drug Groups',
#        'InChIKey', 'InChI', 'SMILES_y', 'Formula', 'KEGG Compound ID',
#        'KEGG Drug ID', 'PubChem Compound ID', 'PubChem Substance ID',
#        'ChEBI ID', 'HET ID', 'ChemSpider ID', 'BindingDB ID'],
#       dtype='object')

# %%
combinedDF.head()
# Out:
#                                           SMILES_x  CHEMSPIDER_ID  \
# 0  BrC1=CN([C@@H]2O[C@H](CO)[C@@H](O)C2)C(=O)NC1=O         5813.0
# 1                       Brc1c2nccnc2ccc1NC=1NCCN=1         2341.0
# 2          Brc1cc(cc(Br)c1O)C(=O)c1c2c(oc1CC)cccc2         2243.0
# 3               Brc1ccc(cc1)[C@H](CCN(C)C)c1ncccc1        16068.0
# 4                          Brc1ccccc1C[N+](CC)(C)C         2337.0
#
#        CHEMBL_ID CHEMBL_KNOWN_DRUG         CHEMBL_NAME  \
# 0   CHEMBL222280                No         BROXURIDINE
# 1      CHEMBL844               Yes         BRIMONIDINE
# 2   CHEMBL388590                No       BENZBROMARONE
# 3  CHEMBL1201287               Yes  DEXBROMPHENIRAMINE
# 4  CHEMBL1199080               Yes           BRETYLIUM
#
#                                CHEMBL_ALTERNATE_NAME  CLINICALTRIALS_DB  \
# 0  SID50105447|SID17389223|SID90341500|SID5646351...                  1
# 1  Alphagan|Brimonidine|UK-14304|Alphagan-P|SID10...                256
# 2  SID11110651|SID26664708|SID24424558|SID5010399...                  2
# 3        SID90341837|Dexbrompheniramine|SID29216402|                  0
# 4                 SID50113155|Bretylium|SID50113154|                  0
#
#   CONCENTRATION_uM DrugBank ID                Name      ...       \
# 0               10     DB12028         Broxuridine      ...
# 1               10     DB00484         Brimonidine      ...
# 2               10     DB12319       Benzbromarone      ...
# 3               10     DB00405  Dexbrompheniramine      ...
# 4               17     DB01158           Bretylium      ...
#
#                                             SMILES_y      Formula  \
# 0  [H][C@]1(O)C[C@@]([H])(O[C@]1([H])CO)N1C=C(Br)...  C9H11BrN2O5
# 1                   BrC1=C(NC2=NCCN2)C=CC2=NC=CN=C12   C11H10BrN5
# 2   CCC1=C(C(=O)C2=CC(Br)=C(O)C(Br)=C2)C2=CC=CC=C2O1  C17H12Br2O3
# 3          CN(C)CC[C@@H](C1=CC=C(Br)C=C1)C1=CC=CC=N1   C16H19BrN2
# 4                         CC[N+](C)(C)CC1=CC=CC=C1Br    C11H17BrN
#
#   KEGG Compound ID KEGG Drug ID PubChem Compound ID PubChem Substance ID  \
# 0              NaN          NaN              6035.0          347828343.0
# 1           C07886       D07540              2435.0           46507305.0
# 2              NaN       D01056              2333.0          347828582.0
# 3              NaN          NaN             16960.0           46505186.0
# 4           C06855       D00645              2431.0           46505320.0
#
#    ChEBI ID HET ID  ChemSpider ID  BindingDB ID
# 0  472552.0    U33         5813.0    50207303.0
# 1    3175.0    NaN         2341.0       34572.0
# 2    3023.0    NaN         2243.0    50158460.0
# 3   59269.0    NaN        16068.0           NaN
# 4    3172.0    NaN         2337.0           NaN
#
# [5 rows x 24 columns]

# %%
## molecular calculator
from rdkit import Chem
from mordred import Calculator, descriptors
calc = Calculator(descriptors, ignore_3D = True)

# %%
mols = [Chem.MolFromSmiles(smi) for smi in combinedDF['SMILES_x']]

# %%
calDF = calc.pandas(mols)
# Out:
#  28%|██▊       | 209/747 [00:29<03:30,  2.56it/s]
# /Users/gmc3001/anaconda3/envs/eclipse/lib/python3.5/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  30%|██▉       | 223/747 [00:32<02:57,  2.96it/s]
# /Users/gmc3001/anaconda3/envs/eclipse/lib/python3.5/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  41%|████      | 307/747 [00:48<02:39,  2.75it/s]
# /Users/gmc3001/anaconda3/envs/eclipse/lib/python3.5/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  79%|███████▉  | 591/747 [01:33<01:35,  1.63it/s]
# /Users/gmc3001/anaconda3/envs/eclipse/lib/python3.5/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 747/747 [01:49<00:00,  6.80it/s]

# %%
calDF = calDF.set_index(combinedDF['CHEMBL_ID'])
calDF.head()
# Out:
#                      ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  \
# CHEMBL_ID
# CHEMBL222280   13.003721  11.805899      0      0  21.163013  2.430127
# CHEMBL844      13.423098  11.209659      0      3  22.818993  2.412409
# CHEMBL388590   17.125041  14.795147      0      0  28.373722  2.499388
# CHEMBL1201287  14.389425  12.216867      0      1  24.221083  2.349628
# CHEMBL1199080   9.579175   9.100648      0      1  15.610374  2.304315
#
#                SpDiam_A     SpAD_A   SpMAD_A   LogEE_A    ...         SRW10  \
# CHEMBL_ID                                                 ...
# CHEMBL222280   4.790842  21.163013  1.244883  3.759503    ...      9.743730
# CHEMBL844      4.818966  22.818993  1.342294  3.784126    ...      9.736193
# CHEMBL388590   4.899958  28.373722  1.289715  4.030858    ...     10.136938
# CHEMBL1201287  4.699256  24.221083  1.274794  3.848879    ...      9.572271
# CHEMBL1199080  4.608630  15.610374  1.200798  3.457889    ...      9.256938
#
#                   TSRW10          MW        AMW  WPath  WPol  Zagreb1  \
# CHEMBL_ID
# CHEMBL222280   63.794961  305.985134  10.928040    505    26     88.0
# CHEMBL844      63.007560  291.011957  10.778221    515    24     90.0
# CHEMBL388590   70.803080  421.915318  12.409274    988    38    118.0
# CHEMBL1201287  51.676805  318.073161   8.370346    718    25     92.0
# CHEMBL1199080  43.893749  242.053888   8.068463    248    16     62.0
#
#                Zagreb2  mZagreb1  mZagreb2
# CHEMBL_ID
# CHEMBL222280     104.0  7.027778  3.777778
# CHEMBL844        106.0  4.305556  3.750000
# CHEMBL388590     143.0  8.000000  4.861111
# CHEMBL1201287    103.0  6.305556  4.305556
# CHEMBL1199080     68.0  5.784722  2.944444
#
# [5 rows x 1613 columns]

# %%
calDF.columns.to_series().groupby(calDF.dtypes).groups
# Out:
# {dtype('bool'): Index(['Lipinski', 'GhoseFilter'], dtype='object'),
#  dtype('int64'): Index(['nAcid', 'nBase', 'nAromAtom', 'nAromBond', 'nAtom', 'nHeavyAtom',
#         'nSpiro', 'nBridgehead', 'nHetero', 'nH',
#         ...
#         'n9FAHRing', 'n10FAHRing', 'n11FAHRing', 'n12FAHRing', 'nG12FAHRing',
#         'nRot', 'Diameter', 'Radius', 'WPath', 'WPol'],
#        dtype='object', length=314),
#  dtype('float64'): Index(['ABC', 'ABCGG', 'SpAbs_A', 'SpMax_A', 'SpDiam_A', 'SpAD_A', 'SpMAD_A',
#         'LogEE_A', 'VE1_A', 'VE2_A',
#         ...
#         'SRW08', 'SRW09', 'SRW10', 'TSRW10', 'MW', 'AMW', 'Zagreb1', 'Zagreb2',
#         'mZagreb1', 'mZagreb2'],
#        dtype='object', length=894),
#  dtype('O'): Index(['AATS5i', 'AATS6i', 'AATS7i', 'AATS8i', 'AATS5pe', 'AATS6pe', 'AATS7pe',
#         'AATS8pe', 'AATS5s', 'AATS6s',
#         ...
#         'MDEO-11', 'MDEO-12', 'MDEO-22', 'MDEN-11', 'MDEN-12', 'MDEN-13',
#         'MDEN-22', 'MDEN-23', 'MDEN-33', 'Vabc'],
#        dtype='object', length=403)}

# %%
## Change data types to float
calDFFloat = calDF.apply(pd.to_numeric,errors='coerce')

# %%
calDFFloat.info()
# Out:
# <class 'mordred._base.pandas_module.MordredDataFrame'>
# Index: 747 entries, CHEMBL222280 to CHEMBL499
# Columns: 1613 entries, ABC to mZagreb2
# dtypes: bool(2), float64(1297), int64(314)
# memory usage: 9.2+ MB

# %%
calDF_test = calDFFloat[calDFFloat.columns[calDFFloat.isnull().mean() < .05]]

# %%
def removeNAColumns(df, percent = 0.05):
    df = df.apply(pd.to_numeric,errors='coerce')
    naCutOff = df.shape[1]*percent
    return(df[df.columns[(df.isna().sum() < naCutOff).values]])

# %%
removeNAColumns(calDF).shape
# Out:
# (747, 1445)

# %%
std_vals = calDF_test.std()

# %%
std_vals
# Out:
# ABC          7.634750
# ABCGG        5.353569
# nAcid        0.576766
# nBase        0.814122
# SpAbs_A     12.383404
#               ...
# WPol        20.532119
# Zagreb1     54.282335
# Zagreb2     67.898093
# mZagreb1     3.720608
# mZagreb2     2.074155
# Length: 1392, dtype: float64

# %%
## Remove std = 0 columns
calDF_ST = calDF_test[calDF_test.columns[calDF_test.std() != 0]]

# %%
calDF_ST
# Out:
#                      ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  \
# CHEMBL222280   13.003721  11.805899    0.0    0.0  21.163013  2.430127
# CHEMBL844      13.423098  11.209659    0.0    3.0  22.818993  2.412409
# CHEMBL388590   17.125041  14.795147    0.0    0.0  28.373722  2.499388
# CHEMBL1201287  14.389425  12.216867    0.0    1.0  24.221083  2.349628
# CHEMBL1199080   9.579175   9.100648    0.0    1.0  15.610374  2.304315
# ...                  ...        ...    ...    ...        ...       ...
# CHEMBL996      21.544123  18.373459    1.0    0.0  34.989139  2.645938
# CHEMBL1175     16.142136  13.559310    0.0    1.0  28.073654  2.397364
# CHEMBL163      38.258967  30.460829    0.0    0.0  62.887929  2.345555
# CHEMBL1472975  23.936889  17.391762    0.0    1.0  40.516221  2.485072
# CHEMBL499      16.061615  13.916519    0.0    1.0  26.106073  2.367286
#
#                SpDiam_A     SpAD_A   SpMAD_A   LogEE_A  ...      SRW10  \
# CHEMBL222280   4.790842  21.163013  1.244883  3.759503  ...   9.743730
# CHEMBL844      4.818966  22.818993  1.342294  3.784126  ...   9.736193
# CHEMBL388590   4.899958  28.373722  1.289715  4.030858  ...  10.136938
# CHEMBL1201287  4.699256  24.221083  1.274794  3.848879  ...   9.572271
# CHEMBL1199080  4.608630  15.610374  1.200798  3.457889  ...   9.256938
# ...                 ...        ...       ...       ...  ...        ...
# CHEMBL996      5.291723  34.989139  1.249612  4.264965  ...  10.666650
# CHEMBL1175     4.786659  28.073654  1.336841  3.972655  ...   9.812304
# CHEMBL163      4.680548  62.887929  1.257759  4.812016  ...  10.505533
# CHEMBL1472975  4.817847  40.516221  1.350541  4.355371  ...  10.389580
# CHEMBL499      4.644873  26.106073  1.243146  3.951442  ...   9.667449
#
#                    TSRW10          MW        AMW    WPath  WPol  Zagreb1  \
# CHEMBL222280    63.794961  305.985134  10.928040    505.0  26.0     88.0
# CHEMBL844       63.007560  291.011957  10.778221    515.0  24.0     90.0
# CHEMBL388590    70.803080  421.915318  12.409274    988.0  38.0    118.0
# CHEMBL1201287   51.676805  318.073161   8.370346    718.0  25.0     92.0
# CHEMBL1199080   43.893749  242.053888   8.068463    248.0  16.0     62.0
# ...                   ...         ...        ...      ...   ...      ...
# CHEMBL996       77.347729  427.050792   9.490018   2071.0  44.0    148.0
# CHEMBL1175      67.683809  297.118735   7.427968    931.0  29.0    106.0
# CHEMBL163      102.893937  720.312761   7.350130  10769.0  69.0    248.0
# CHEMBL1472975   82.310896  426.208947   7.103482   2982.0  49.0    164.0
# CHEMBL499       67.817505  316.156912   7.025709   1063.0  25.0    104.0
#
#                Zagreb2   mZagreb1   mZagreb2
# CHEMBL222280     104.0   7.027778   3.777778
# CHEMBL844        106.0   4.305556   3.750000
# CHEMBL388590     143.0   8.000000   4.861111
# CHEMBL1201287    103.0   6.305556   4.305556
# CHEMBL1199080     68.0   5.784722   2.944444
# ...                ...        ...        ...
# CHEMBL996        179.0  10.812500   6.222222
# CHEMBL1175       123.0   5.305556   4.833333
# CHEMBL163        280.0  17.166667  11.138889
# CHEMBL1472975    198.0   7.611111   6.555556
# CHEMBL499        115.0   7.506944   4.597222
#
# [747 rows x 1258 columns]

# %%
## probably don't need this anymore
calDF_R = calDFFloat.replace({0:np.nan})
calDF_R.head()
calDF_RF = calDF_R[calDF_R.columns[calDF_R.isnull().mean() < .05]]
calDF_RF
calDF_RF_STD = calDF_RF[calDF_RF.columns[calDF_RF.std() != 0]]
calDF_RF_STD
